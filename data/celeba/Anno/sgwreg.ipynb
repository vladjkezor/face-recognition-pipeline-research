# %%
import pandas as pd

# %%
landmarks = pd.read_csv('list_landmarks_celeba.txt', sep=r'\s+', index_col=0)

# %%
landmarks = landmarks.iloc[:20000]

# %%
landmarks
# Out:
#             lefteye_x  lefteye_y  righteye_x  righteye_y  nose_x  nose_y  \
# 000001.jpg        165        184         244         176     196     249
# 000002.jpg        140        204         220         204     168     254
# 000003.jpg        244        104         264         105     263     121
# 000004.jpg        796        539         984         539     930     687
# 000005.jpg        273        169         328         161     298     172
# ...               ...        ...         ...         ...     ...     ...
# 019996.jpg        169        183         224         187     192     221
# 019997.jpg         47        120          87         115      65     142
# 019998.jpg        842        129         886         127     864     157
# 019999.jpg        144        206         218         207     184     250
# 020000.jpg        131        132         183         117     178     157
#
#             leftmouth_x  leftmouth_y  rightmouth_x  rightmouth_y
# ...

# %%
bb = pd.read_csv('list_bbox_celeba.txt', sep=r'\s+', index_col=0)

# %%
bb.iloc[0]
# Out:
# x_1        95
# y_1        71
# width     226
# height    313
# Name: 000001.jpg, dtype: int64
